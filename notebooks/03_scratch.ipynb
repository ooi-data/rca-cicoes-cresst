# %%
import xarray as xr
import cmocean

# %%
ds = xr.open_dataset("../data/axial_base_profiles_20150107_20260511.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 287MB
# Dimensions:                       (profile_number: 23220,
#                                    sea_water_pressure: 220)
# Coordinates:
#   * profile_number                (profile_number) int32 93kB 48 49 ... 23269
#     start_time                    (profile_number) datetime64[ns] 186kB ...
#     peak_time                     (profile_number) datetime64[ns] 186kB ...
#     end_time                      (profile_number) datetime64[ns] 186kB ...
#   * sea_water_pressure            (sea_water_pressure) float64 2kB 0.0 ... 219.0
# Data variables:
#     sea_water_temperature         (profile_number, sea_water_pressure) float64 41MB ...
#     sea_water_practical_salinity  (profile_number, sea_water_pressure) float64 41MB ...
#     corrected_dissolved_oxygen    (profile_number, sea_water_pressure) float64 41MB ...
#     sea_water_density             (profile_number, sea_water_pressure) float64 41MB ...
# ...

# %%
ds.peak_time
# Out:
# <xarray.DataArray 'peak_time' (profile_number: 23220)> Size: 186kB
# array(['2015-01-07T17:57:00.000000000', '2015-01-07T18:51:00.000000000',
#        '2015-01-07T19:46:00.000000000', ..., '2026-05-11T04:07:00.000000000',
#        '2026-05-11T06:17:00.000000000', '2026-05-11T08:47:00.000000000'],
#       shape=(23220,), dtype='datetime64[ns]')
# Coordinates:
#   * profile_number  (profile_number) int32 93kB 48 49 50 ... 23267 23268 23269
#     start_time      (profile_number) datetime64[ns] 186kB ...
#     peak_time       (profile_number) datetime64[ns] 186kB 2015-01-07T17:57:00...
#     end_time        (profile_number) datetime64[ns] 186kB ...

# %%
import hvplot.xarray

# ds.swap_dims({"profile_number": "peak_time"}).sea_water_temperature.hvplot.quadmesh(
#     x="peak_time",
#     y="sea_water_pressure",
#     colorbar=True,
#     flip_yaxis=True,
#     cmap="cmo.thermal",
#     width=900,
#     height=400,
# )
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ab3be897-707e-4709-87e4-e4da048ee941'>
#   <div id="d3c073f1-65d0-4726-af40-1ab1431ac0cb" data-root-id="ab3be897-707e-4709-87e4-e4da048ee941" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
